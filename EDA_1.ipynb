# %%
from    typing      import  *
from    pathlib     import  Path

import  numpy               as  np
import  matplotlib.pyplot   as  plt

from    utils       import  *

# %%
import torch
a = torch.arange(10).reshape(2, 5)
b = torch.tensor([4.5], requires_grad=True)
print(torch.clamp_min(a, b))
# Out:
# tensor([[4.5000, 4.5000, 4.5000, 4.5000, 4.5000],
#         [5.0000, 6.0000, 7.0000, 8.0000, 9.0000]], grad_fn=<ClampMinBackward1>)

# %%
base_path = Path(BASE_PATHS[MVTEC_AD])

# %%
for d in base_path.glob('*'):
    print(d)

# %%
for d in (base_path/'zipper'/'train'/'good').glob('*'):
    print(d)
print('-'*50)
for d in (base_path/'zipper'/'test'/'split_teeth').glob('*'):
    print(d)

# %%
np.load
